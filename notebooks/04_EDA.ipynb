# %% [markdown]
# # Phase 4: Exploratory Data Analysis (EDA)
#
# This notebook performs comprehensive exploratory data analysis on the cleaned datasets from Phase 3.
#
# ## Objectives
# - Understand data distributions and patterns
# - Identify key insights and relationships
# - Generate visualizations for reports
# - Prepare foundation for modeling phase
#
# ## Datasets
# - Product Information (25 products)
# - Weekly Sales (2600 records)
# - External Features (104 weeks)

# %% [markdown]
# ## 1. Setup and Data Loading

# %%
import pandas as pd
import sys
import os
from pathlib import Path

# Add project root to path
sys.path.append('..')

from src.eda import *

# Load cleaned datasets
print("Loading cleaned datasets...")
df_product = pd.read_csv('../data/processed/product_info_clean.csv')
df_sales = pd.read_csv('../data/processed/weekly_sales_clean.csv')
df_external = pd.read_csv('../data/processed/external_features_clean.csv')

# Convert date columns
df_product['Launch_Date'] = pd.to_datetime(df_product['Launch_Date'])
df_sales['Week_End_Date'] = pd.to_datetime(df_sales['Week_End_Date'])
df_external['Week_End_Date'] = pd.to_datetime(df_external['Week_End_Date'])

print("Data loading complete:")
print(f"- Product Info: {df_product.shape}")
print(f"- Weekly Sales: {df_sales.shape}")
print(f"- External Features: {df_external.shape}")
# Out:
# Loading cleaned datasets...
# Data loading complete:
# - Product Info: (25, 10)
# - Weekly Sales: (2600, 7)
# - External Features: (104, 6)

# %% [markdown]
# ## 2. Basic EDA

# %% [markdown]
# ### 2.1 Dataset Overview

# %%
# Dataset overview
overview = dataset_overview(df_product, df_sales, df_external)
print("Dataset Overview:")
overview
# Out:
# Dataset Overview:
#              Dataset  Rows  Columns  \
# 0       Product Info    25       10
# 1       Weekly Sales  2600        7
# 2  External Features   104        6
#
#                                    Date_Range
# 0  2022-01-02 00:00:00 to 2022-12-22 00:00:00
# 1  2023-01-07 00:00:00 to 2024-12-28 00:00:00
# 2  2023-01-07 00:00:00 to 2024-12-28 00:00:00

# %% [markdown]
# ### 2.2 Summary Statistics

# %%
# Summary statistics
stats = summary_statistics(df_product, df_sales, df_external)
print("Summary Statistics Generated:")
for dataset_name, df_stats in stats.items():
    print(f"\n{dataset_name}:")
    print(df_stats)
# Out:
# Summary Statistics Generated:
#
# Product Info:
#              MSRP  Wholesale_Price
# count   25.000000        25.000000
# mean   120.720000        72.743600
# std     37.850055        24.022595
# min     59.000000        32.650000
# 25%     94.000000        55.080000
# 50%    127.000000        72.570000
# 75%    149.000000        91.410000
# max    191.000000       114.190000
#
# Weekly Sales:
#           Qty_Sold    Inventory     On_Order      Returns     Discount
# count  2600.000000  2600.000000  2600.000000  2600.000000  2600.000000
# mean     56.454615   397.295769   176.378077     2.305385     9.994231
# std      27.501251    60.994836    71.658615     1.740530     7.051313
# min      14.000000   274.000000    50.000000     0.000000     0.000000
# 25%      33.000000   347.000000   115.000000     1.000000     5.000000
# 50%      53.000000   397.000000   178.000000     2.000000    10.000000
# 75%      76.000000   449.000000   239.000000     3.000000    15.000000
# ...

# %% [markdown]
# ### 2.3 Category Distribution

# %%
# Category distribution
category_distribution(df_product)
print("Category distribution chart saved to reports/charts/")
# Out:
# Category distribution chart saved to reports/charts/

# %% [markdown]
# ### 2.4 Gender Distribution

# %%
# Gender distribution
gender_distribution(df_product)
print("Gender distribution chart saved to reports/charts/")
# Out:
# Gender distribution chart saved to reports/charts/

# %% [markdown]
# ### 2.5 Price Distributions

# %%
# Price distributions
price_distributions(df_product)
print("Price distributions chart saved to reports/charts/")
# Out:
# Price distributions chart saved to reports/charts/

# %% [markdown]
# ## 3. Weekly Sales Analysis

# %% [markdown]
# ### 3.1 Total Weekly Sales Trend

# %%
# Weekly sales trend
weekly_sales_trend(df_sales)
print("Weekly sales trend chart saved to reports/charts/")
# Out:
# Weekly sales trend chart saved to reports/charts/

# %% [markdown]
# ### 3.2 Product-wise Total Sales

# %%
# Product total sales
product_total_sales(df_sales)
print("Product total sales chart saved to reports/charts/")
# Out:
# Product total sales chart saved to reports/charts/

# %% [markdown]
# ### 3.3 Top 10 Products by Sales

# %%
# Top 10 products
top_10 = top_products(df_sales)
print("Top 10 products table saved to reports/tables/")
print("\nTop 10 Products by Total Sales:")
top_10
# Out:
# Top 10 products table saved to reports/tables/
#
# Top 10 Products by Total Sales:
# Product_ID
# TE006    10090
# TE019    10086
# TE009     9747
# TE021     9325
# TE005     9300
# TE015     8046
# TE011     8038
# TE008     6882
# TE004     6735
# TE018     6717
# Name: Qty_Sold, dtype: int64

# %% [markdown]
# ### 3.4 Sales Distribution

# %%
# Sales distribution
sales_distribution(df_sales)
print("Sales distribution chart saved to reports/charts/")
# Out:
# Sales distribution chart saved to reports/charts/

# %% [markdown]
# ### 3.5 Returns Distribution

# %%
# Returns distribution
returns_distribution(df_sales)
print("Returns distribution chart saved to reports/charts/")
# Out:
# Returns distribution chart saved to reports/charts/

# %% [markdown]
# ### 3.6 Discount Distribution

# %%
# Discount distribution
discount_distribution(df_sales)
print("Discount distribution chart saved to reports/charts/")
# Out:
# Discount distribution chart saved to reports/charts/

# %% [markdown]
# ## 4. Time Series Insights

# %% [markdown]
# ### 4.1 Rolling Weekly Sales Trend

# %%
# Rolling trend
rolling_trend(df_sales)
print("Rolling sales trend chart saved to reports/charts/")
# Out:
# Rolling sales trend chart saved to reports/charts/

# %% [markdown]
# ### 4.2 Monthly Aggregated Sales

# %%
# Monthly sales
monthly_sales(df_sales)
print("Monthly sales chart saved to reports/charts/")
# Out:
# Monthly sales chart saved to reports/charts/

# %% [markdown]
# ### 4.3 Seasonality Visuals

# %%
# Seasonality visuals
seasonality_visuals(df_sales)
print("Seasonality visuals chart saved to reports/charts/")
# Out:
# Seasonality visuals chart saved to reports/charts/

# %% [markdown]
# ## 5. External Features Exploration

# %% [markdown]
# ### 5.1 Rainfall Trend

# %%
# Rainfall trend
rainfall_trend(df_external)
print("Rainfall trend chart saved to reports/charts/")
# Out:
# Rainfall trend chart saved to reports/charts/

# %% [markdown]
# ### 5.2 Temperature Trend

# %%
# Temperature trend
temperature_trend(df_external)
print("Temperature trend chart saved to reports/charts/")
# Out:
# Temperature trend chart saved to reports/charts/

# %% [markdown]
# ### 5.3 Promo Event / Holiday Frequency

# %%
# Promo and holiday frequency
promo_holiday_frequency(df_external)
print("Promo/holiday frequency chart saved to reports/charts/")
# Out:
# Promo/holiday frequency chart saved to reports/charts/

# %% [markdown]
# ## 6. Relationship Analysis

# %% [markdown]
# ### 6.1 Discount vs Quantity Sold

# %%
# Discount vs sales
discount_vs_sales(df_sales)
print("Discount vs sales chart saved to reports/charts/")
# Out:
# Discount vs sales chart saved to reports/charts/

# %% [markdown]
# ### 6.2 Returns vs Quantity Sold

# %%
# Returns vs sales
returns_vs_sales(df_sales)
print("Returns vs sales chart saved to reports/charts/")
# Out:
# Returns vs sales chart saved to reports/charts/

# %% [markdown]
# ### 6.3 Weather vs Total Sales

# %%
# Weather vs sales
weather_vs_sales(df_sales, df_external)
print("Weather vs sales exploratory plots saved to reports/charts/")
# Out:
# Weather vs sales exploratory plots saved to reports/charts/

# %% [markdown]
# ## 7. EDA Summary
#
# ### Key Findings:
# - **Dataset Overview**: Comprehensive view of all three datasets with their dimensions and date ranges
# - **Product Analysis**: Distribution across categories, genders, and price ranges
# - **Sales Patterns**: Identified top-performing products and sales trends over time
# - **Time Series**: Rolling averages and monthly aggregations reveal seasonal patterns
# - **External Factors**: Weather trends and promotional event frequencies analyzed
# - **Relationships**: Initial exploration of discount, returns, and weather impacts on sales
#
# ### Generated Outputs:
# - **Charts (15 total)**: All saved to `reports/charts/` with professional formatting
# - **Tables (3 total)**: Dataset overview, summary statistics, and top products saved to `reports/tables/`
#
# ### Next Steps:
# - Use insights for feature engineering in Phase 5
# - Consider correlations identified for modeling in Phase 6
# - Review seasonal patterns for forecasting in Phase 7
#
# All analyses completed successfully. Ready for Phase 5.
